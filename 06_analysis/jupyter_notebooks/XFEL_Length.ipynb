# %% [markdown]
# ### Imports

# %%
import numpy as _np
import matplotlib.pyplot as _plt
import sys
import os

# Add the parent folder to sys.path
parent_folder = os.path.abspath('..')
if parent_folder not in sys.path:
    sys.path.append(parent_folder)

# Import the module from the parent folder
import XFEL_BPM

# %% [markdown]
# ### Date and prefix

# %%
date = "2025_02_11"
save_name_prefix = "plots/XFEL/Length/" + date + "_XFEL_plot"

# %% [markdown]
# # Bunch Lenght

# %%
CD1 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_1_for_100000_trains.pk")
CD2 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_92_for_100000_trains.pk")
#CD3 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_453_for_100000_trains.pk")

# %%
CD1.PlotLengthAndHistPer(percentile=0.95, bins=50, figsize=[12, 5])
_plt.savefig("{}_Bunch_length_first_bunch".format(save_name_prefix), dpi=300, bbox_inches='tight')

# %%
CD2.PlotLengthAndHistPer(percentile=0.95, bins=50, figsize=[12, 5])
_plt.savefig("{}_Bunch_length_line_bunch".format(save_name_prefix), dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Date and prefix

# %%
date = "2025_02_11"
save_name_prefix = "plots/XFEL/Size/" + date + "_XFEL_plot"
