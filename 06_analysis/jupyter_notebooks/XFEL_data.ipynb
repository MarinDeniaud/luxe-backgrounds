# %% [markdown]
# ### Imports

# %%
import numpy as _np
import matplotlib.pyplot as _plt
import sys
import os

# Add the parent folder to sys.path
parent_folder = os.path.abspath('..')
if parent_folder not in sys.path:
    sys.path.append(parent_folder)

# Import the module from the parent folder
import XFEL_BPM

# %% [markdown]
# ### Date and prefix

# %%
date = "2025_01_22"
save_name_prefix = "plots/XFEL/" + date + "_XFEL_plot"

# %% [markdown]
# ### Get bunch pattern

# %%
file = '../XFEL_data/matched_linac_main_run2148_file109482_20231119T155947.all.hdf5'
df_bp = XFEL_BPM.getH5dataInDF(file, getPosition=False)
# Out:
# Load matched_linac_main_run2148_file109482_20231119T155947.all.hdf5 | 49 bpms, 3155 trains, 2708 bunches: |██████████████████████████████████████████████████| 100.0% Complete

# %%
df_bp[df_bp['Valid'] == 1]
# Out:
#                                  Valid
# BPM          TrainID    BunchID
# BPMI.1860.TL 1856425974 0          1.0
#                         1          1.0
#                         2          1.0
#                         3          1.0
#                         4          1.0
# ...                                ...
# BPME.2235.T2 1856429145 2126       1.0
#                         2174       1.0
#                         2222       1.0
#                         2270       1.0
#                         2318       1.0
#
# [128589930 rows x 1 columns]

# %%
XFEL_BPM.plotBunchPattern(df_bp, sample=1, figsize=[14, 3])

# %% [markdown]
# ### Check if consistant data

# %%
XFEL_BPM.checkTrainBunchConsistancy(df_bp)

# %% [markdown]
# # Get H5 data in DF

# %%
df = XFEL_BPM.getH5dataInDF('../XFEL_data/reduced_matched_linac_main_run2148_file114155_20231120T155943.all.hdf5')
# Out:
# Load reduced_matched_linac_main_run2148_file114155_20231120T155943.all.hdf5 | 49 bpms, 3391 trains, 9 bunches: |██████████████████████████████████████████████████| 100.0% Complete

# %%
#df

# %% [markdown]
# ## Jitter and Noise

# %%
XFEL_BPM.plotJitterAndNoise(df, '../../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, plotNoise=True, plotSigma=True, figsize=[14, 10], xlim=[1900, 2200], height_ratios=[2,2,2])
_plt.savefig("{}_Jitter_Noise_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, plotNoise=True, figsize=[14, 6], height_ratios=[2,1])
_plt.savefig("{}_Jitter_Noise_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %% [markdown]
# ## Jitter and Optics

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, plotBeta=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Beta_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, plotBeta=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Beta_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, plotDisp=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Disp_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, plotDisp=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Disp_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %% [markdown]
# ## Jitter and Sigma

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, esprd=1e-6, plotSigma=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Sigma_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, esprd=1e-6, plotSigma=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Sigma_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, esprd=3e-6, plotSigma=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Sigma_for_T1_with_adjusted_Esprd".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %% [markdown]
# ## Max angle Jitter

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, plotAngle=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Angle_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, plotAngle=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Angle_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %% [markdown]
# ## Jitter and Position Mean

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T4D', bunches=6, plotMean=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Mean_for_T2".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8541

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=3, plotMean=True, figsize=[14, 8])
_plt.savefig("{}_Jitter_Mean_for_T1".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=8411

# %%
XFEL_BPM.plotJitterAndNoise(df, '../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=0, figsize=[14, 4])
# Out:
# Mad8.readTwissFile > nrec=8411

# %%
df_average = XFEL_BPM.getH5dataInDF('XFEL_data/matched_linac_main_run2148_file109482_20231119T155947.all.hdf5')
# Out:
# Load matched_linac_main_run2148_file109482_20231119T155947.all.hdf5 | 49 bpms, 3155 trains, 2708 bunches: |██████████████████████████████████████████████████| 100.0% Complete

# %%
XFEL_BPM.plotJitterAverageForAllBunches(df_average, trains=None, Smin=1900, Smax=1950, sample=10, SigmaRatio=False, figsize=[14, 6])
_plt.savefig("{}_Jitter_Average_per_bunch_ID".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=6662
# Mad8.readTwissFile > nrec=8411
# Mad8.readTwissFile > nrec=8541
# Caluclate average jitter for bunch 243/243: |██████████████████████████████████████████████████| 100.0% Complete

# %%
XFEL_BPM.plotJitterAverageForAllBunches(df_average, trains=None, Smin=1900, Smax=1950, SigmaRatio=True, sample=10, figsize=[14, 6])
_plt.savefig("{}_Jitter_Sigma_Average_per_bunch_ID".format(save_name_prefix), dpi=300, bbox_inches='tight')
# Out:
# Mad8.readTwissFile > nrec=6662
# Mad8.readTwissFile > nrec=8411
# Mad8.readTwissFile > nrec=8541
# Caluclate average jitter for bunch 243/243: |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# # Resolution (in fact it's the same as the 'noise')

# %%
XFEL_BPM.plotResolution(df, '../../01_mad8/XFEL_Lattice_9/TWISS_T5D', bunches=6, figsize=[14, 5], ylog=True)
# Out:
# Mad8.readTwissFile > nrec=8411

# %% [markdown]
# # Energy

# %%
E_CL_1 = XFEL_BPM.EnergyPerBunchData("../XFEL_data/marin-energy-measurements/mp2234914117-CL.pkl")

# %%
E_CL_1.PlotAll(minCut=450, maxCut=510, figsize=[12,5])
_plt.savefig("{}_Energy_per_bunch_in_train".format(save_name_prefix), dpi=300, bbox_inches='tight')

# %%
E = XFEL_BPM.EnergyPerTrainData('../XFEL_data/matched_linac_main_run2148_file109482_20231119T155947.all.hdf5')
# Out:
# Loaded file 'matched_linac_main_run2148_file109482_20231119T155947.all.hdf5'
# Loading 49 bpms, 3155 trains and 2708 bunches in df: |██████████████████████████████████████████████████| 100.0% Complete
# Loading 49 bpms, 3155 trains and 2708 bunches in df: |██████████████████████████████████████████████████| 100.0% Complete

# %%
E.PlotAll(figsize=[12,5])
_plt.savefig("{}_Energy_per_train".format(save_name_prefix), dpi=300, bbox_inches='tight')

# %% [markdown]
# # Bunch Lenght

# %%
CD1 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_1_for_100000_trains.pk")
CD2 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_92_for_100000_trains.pk")
CD3 = XFEL_BPM.CrispData("../XFEL_data/crisp_bunch_453_for_100000_trains.pk")

# %%
CD1.plotLengthPerTrain()

# %%
CD1.plotLenghtHist(figsize=[7, 5])

# %%
CD2.plotLengthPerTrain()

# %%
CD2.plotLenghtHist(figsize=[7, 5])

# %% [markdown]
# # Arrival Time

# %%
TD = XFEL_BPM.ArrivalTimeData('../XFEL_data/matched_linac_main_run2148_file109482_20231119T155947.all.hdf5')
# Out:
# Load matched_linac_main_run2148_file109482_20231119T155947.all.hdf5 | 49 bpms, 3155 trains, 2708 bunches: |██████████████████████████████████████████████████| 100.0% Complete

# %%
TD.PlotTimeAndHistPer(index='BunchID', Train=1856425974, BPM="BPMI.1860.TL", minCut=350, maxCut=2350, figsize=[12, 5])

# %%
TD.PlotTimeAndHistPer(index='TrainID', Bunch=0, BPM="BPMI.1860.TL", minCut=0, maxCut=None, figsize=[12, 5])

# %% [markdown]
# # Emittance

# %%
import scipy.io
file = '../XFEL_data/all-wirescan-results-for-marin/2024-09-01T015043_quad_scan_proj_L3_OTRBW_1523_L3_OTRBW_1597_L3_OTRBW_1635_L3_wire.mat'
mat = scipy.io.loadmat(file)

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'result', 'quad_scan', 'conf', 'measurement_data'])

# %%
type(mat['measurement_data'][0, 0].dtype)
# Out:
# numpy.dtype[void]

# %%
mat['measurement_data'][0, 0].dtype.names[5]
# Out:
# 'gaussian_fit_params_y'

# %%
mat['measurement_data'][0, 0][5]
# Out:
# array([[array([[327, 3.7e+04, 0.59, 0.0613]])],
#        [array([[261, 3.5e+04, 0.598, 0.0365]])],
#        [array([[269, 3.71e+04, 0.598, 0.0363]])],
#        [array([[-0.0589, 2.37, 0.546, 0.234]])],
#        [array([[-0.00856, 2.19, 0.567, 0.174]])]], dtype=object)

# %%
_plt.plot(mat['measurement_data'][0, 0][0], mat['measurement_data'][0, 0][1][:,0:3])
# Out:
# [<matplotlib.lines.Line2D at 0x33eabc6d0>,
#  <matplotlib.lines.Line2D at 0x33eabc910>,
#  <matplotlib.lines.Line2D at 0x33eabcbd0>]

# %%
mat['quad_scan'].dtype.names
# Out:
# ('slice_measurement',
#  'all_quads',
#  'scan_quads',
#  'scan_quads_v',
#  'common_power_supply_v',
#  'all_screens',
#  'screen_positions',
#  'reference_point',
#  'twiss_at_reference_point',
#  'beta_functions',
#  'wire',
#  'screen')

# %%
mat['quad_scan'].dtype.names[10]
# Out:
# 'wire'

# %%
mat['quad_scan'][0,0][10]
# Out:
# dtype([('quad_strength', 'O'), ('measurement_screen', 'O'), ('screen_position', 'O'), ('betax_at_screen', 'O'), ('betay_at_screen', 'O'), ('psix_at_screen', 'O'), ('psiy_at_screen', 'O'), ('tranfer_matrices', 'O')])
