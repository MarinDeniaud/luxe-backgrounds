# %%
import numpy as _np
import matplotlib.pyplot as _plt
import pybdsim as _bd
import pymad8 as _m8
import time

# %%
bdsimfile1000_0 = "../../04_dataLocal/beamTracking/00_TL-T20-FF_bpms-for-elbex_1000-particles.root"
bdsimfile10000_0 = "../../04_dataLocal/beamTracking/00_TL-T20-FF_bpms-for-elbex_10000-particles.root"
bdsimfile10000_1 = "../../04_dataLocal/beamTracking/01_TL-T20-FF_bpms-for-elbex_10000-particles.root"

# %%
bdsimOutput = _bd.Data.Load(bdsimfile1000_0)
bdsimOutputPandas = _bd.DataPandas.BDSIMOutput(bdsimfile1000_0)
# Out:
# BDSIM output file - using DataLoader

# %%
bdsimOutputPandas.get_primary()
# Out:
#      file_idx  primary_idx             x        xp             y        yp  \
# 0           0            0 -6.168075e-07 -0.000008 -1.063003e-05  0.000002
# 1           0            0 -3.274349e-06  0.000005  5.624933e-06 -0.000004
# 2           0            0 -2.449665e-06  0.000004 -4.494548e-07 -0.000003
# 3           0            0 -3.078970e-06  0.000007 -3.024501e-05  0.000002
# 4           0            0 -1.423392e-06  0.000008 -4.924707e-06 -0.000007
# ..        ...          ...           ...       ...           ...       ...
# 995         0            0  1.402200e-06 -0.000013 -3.195773e-05  0.000006
# 996         0            0  9.833140e-07 -0.000019  1.651602e-06  0.000003
# 997         0            0 -3.239548e-06  0.000007 -2.149700e-06  0.000010
# 998         0            0 -3.029744e-06 -0.000018  1.291631e-05  0.000004
# 999         0            0  3.620096e-06  0.000005  9.339544e-07  0.000003
#
#        z   zp         T     theta     energy  partID  trackID  weight  \
# 0    0.0  1.0 -0.000059  0.000009  14.000014      11        0     1.0
# 1    0.0  1.0 -0.000067  0.000006  14.000005      11        0     1.0
# 2    0.0  1.0  0.000053  0.000005  13.999983      11        0     1.0
# 3    0.0  1.0  0.000065  0.000008  13.999976      11        0     1.0
# 4    0.0  1.0 -0.000144  0.000010  13.999990      11        0     1.0
# ..   ...  ...       ...       ...        ...     ...      ...     ...
# 995  0.0  1.0  0.000071  0.000014  14.000016      11        0     1.0
# 996  0.0  1.0 -0.000065  0.000019  13.999989      11        0     1.0
# 997  0.0  1.0  0.000155  0.000012  13.999990      11        0     1.0
# 998  0.0  1.0 -0.000028  0.000018  14.000017      11        0     1.0
# 999  0.0  1.0  0.000031  0.000006  14.000002      11        0     1.0
#
#      turnNumber
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 995           1
# 996           1
# 997           1
# 998           1
# 999           1
#
# [1000 rows x 15 columns]

# %%
bdsimOutputPandas.get_sampler('QH9T20.')
# Out:
#      file_idx  event_idx         x            xp         y            yp    z  \
# 0           0          0 -0.000011  1.780353e-06 -0.000018 -3.754918e-06  0.0
# 1           0          1  0.000003  2.262307e-06  0.000031  4.694783e-06  0.0
# 2           0          2  0.000003  1.620719e-06  0.000017  2.099670e-06  0.0
# 3           0          3  0.000007  1.720679e-06 -0.000031 -8.205497e-06  0.0
# 4           0          4  0.000009  1.458617e-07  0.000043  4.646849e-06  0.0
# ..        ...        ...       ...           ...       ...           ...  ...
# 995         0        995 -0.000015  5.968254e-07 -0.000055 -1.145562e-05  0.0
# 996         0        996 -0.000022  1.839942e-06 -0.000021 -2.310999e-06  0.0
# 997         0        997  0.000006  1.884839e-06 -0.000070 -8.941469e-06  0.0
# 998         0        998 -0.000024  5.343561e-06 -0.000019 -5.212707e-07  0.0
# 999         0        999  0.000009 -4.055741e-06 -0.000019 -2.188543e-06  0.0
#
#       zp           T     energy  partID  trackID  weight
# 0    1.0  870.232422  14.000014      11        1     1.0
# 1    1.0  870.232422  14.000005      11        1     1.0
# 2    1.0  870.232544  13.999983      11        1     1.0
# 3    1.0  870.232544  13.999976      11        1     1.0
# 4    1.0  870.232361  13.999990      11        1     1.0
# ..   ...         ...        ...     ...      ...     ...
# 995  1.0  870.232544  14.000016      11        1     1.0
# 996  1.0  870.232422  13.999989      11        1     1.0
# 997  1.0  870.232666  13.999990      11        1     1.0
# 998  1.0  870.232483  14.000017      11        1     1.0
# 999  1.0  870.232544  14.000002      11        1     1.0
#
# [1000 rows x 13 columns]

# %%
bdsimOutputPandas.get_sampler('DTOIP0.')
# Out:
#      file_idx  event_idx         x            xp         y        yp    z  \
# 0           0          0  0.000006 -4.516484e-07 -0.000006  0.000004  0.0
# 1           0          1 -0.000001 -5.005735e-06 -0.000001 -0.000005  0.0
# 2           0          2 -0.000001 -3.770132e-06 -0.000004 -0.000002  0.0
# 3           0          3 -0.000003 -4.852023e-06 -0.000020  0.000008  0.0
# 4           0          4 -0.000004 -2.477877e-06 -0.000012 -0.000006  0.0
# ..        ...        ...       ...           ...       ...       ...  ...
# 995         0        995  0.000008  2.712885e-06 -0.000017  0.000012  0.0
# 996         0        996  0.000012  2.415171e-06  0.000005  0.000003  0.0
# 997         0        997 -0.000003 -5.077795e-06  0.000011  0.000010  0.0
# 998         0        998  0.000014 -3.456671e-06  0.000015  0.000001  0.0
# 999         0        999 -0.000006  4.976327e-06  0.000004  0.000003  0.0
#
#       zp           T     energy  partID  trackID  weight
# 0    1.0  964.195801  14.000014      11        1     1.0
# 1    1.0  964.195801  14.000005      11        1     1.0
# 2    1.0  964.195923  13.999983      11        1     1.0
# 3    1.0  964.195923  13.999976      11        1     1.0
# 4    1.0  964.195679  13.999990      11        1     1.0
# ..   ...         ...        ...     ...      ...     ...
# 995  1.0  964.195923  14.000016      11        1     1.0
# 996  1.0  964.195801  13.999989      11        1     1.0
# 997  1.0  964.195984  13.999990      11        1     1.0
# 998  1.0  964.195801  14.000017      11        1     1.0
# 999  1.0  964.195862  14.000002      11        1     1.0
#
# [1000 rows x 13 columns]

# %%
import pandas as _pd

def getBdsimTrackInDF(inputfilename):

    data = _bd.Data.Load(inputfilename)
    e = data.GetEvent()
    et = data.GetEventTree()
    npart = et.GetEntries()

    sampler_names = e.GetSamplerNames()
    data_dict = {'S': [], 'X': [], 'Y': [], 'PX': [], 'PY': []}
    sampler_list = []
    for particle in range(npart):
        et.GetEntry(particle)
        for i_sampler, sampler in enumerate(sampler_names):
            if particle == 0 :
                sampler_name = str(sampler).replace('.', '')
                sampler_list.append(sampler_name)
            sampler_data = e.GetSampler(sampler)
            data_dict['S'].append(sampler_data.S)
            data_dict['X'].append(sampler_data.x[0])
            data_dict['Y'].append(sampler_data.y[0])
            data_dict['PX'].append(sampler_data.xp[0])
            data_dict['PY'].append(sampler_data.yp[0])
    for key in data_dict:
        data_dict[key] = _np.asarray(data_dict[key]).flatten()
    df = _pd.DataFrame(data_dict, index=_pd.MultiIndex.from_product([range(s) for s in (npart, len(sampler_names))], 
                                                                    names=['PARTICLE', 'SAMPLER']))
    df.index.set_levels([sampler_list], level=[1], inplace=True)
    return df

# %%
def getBdsimTrackInDF2(inputfilename):
    data = _bd.DataPandas.BDSIMOutput(inputfilename)
    data_dict = {'S': [], 'X': [], 'Y': [], 'PX': [], 'PY': []}
    S = data.get_model()['endS']
    npart = data.get_events().shape[0]
    for i, sampler_name in enumerate(data.get_sampler_names()):
        df = data.get_sampler(sampler_name)
        data_dict['S'].append([S[i]]*npart)
        data_dict['X'].append(df.x)
        data_dict['Y'].append(df.y)
        data_dict['PX'].append(df.xp)
        data_dict['PY'].append(df.yp)
    for key in data_dict:
        data_dict[key] = _np.asarray(data_dict[key]).flatten()
    df = _pd.DataFrame(data_dict, index=_pd.MultiIndex.from_product([range(s) for s in (len(S), npart)], 
                                                                    names=['SAMPLER', 'PARTICLE']))
    df.index.set_levels(data.get_sampler_names(), level=[0], inplace=True)
    return df
