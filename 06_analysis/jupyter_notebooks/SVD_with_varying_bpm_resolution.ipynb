# %%
import numpy as _np
import matplotlib.pyplot as _plt
import pybdsim as _bd
import pymad8 as _m8

# %%
bdsimfile = "../../04_dataLocal/beamTracking/00_TL-T20-FF_bpms-for-elbex_10000-particles.root"

# %%
bdsimOutput = _bd.DataPandas.BDSIMOutput(bdsimfile)

# %%
bdsimOutput.get_primary()
# Out:
#                  x            xp             y        yp    z   zp         T  \
# 0    -6.168075e-07 -8.360191e-06 -1.063003e-05  0.000002  0.0  1.0 -0.000059
# 1    -3.274349e-06  4.992526e-06  5.624933e-06 -0.000004  0.0  1.0 -0.000067
# 2    -2.449665e-06  4.223338e-06 -4.494548e-07 -0.000003  0.0  1.0  0.000053
# 3    -3.078970e-06  7.474253e-06 -3.024501e-05  0.000002  0.0  1.0  0.000065
# 4    -1.423392e-06  7.913262e-06 -4.924707e-06 -0.000007  0.0  1.0 -0.000144
# ...            ...           ...           ...       ...  ...  ...       ...
# 9995 -2.130640e-06  7.603851e-07  1.388440e-07  0.000004  0.0  1.0 -0.000133
# 9996  3.105218e-06  5.520279e-06 -1.673063e-05  0.000002  0.0  1.0 -0.000083
# 9997  4.746859e-07 -1.019701e-05 -4.269330e-06  0.000002  0.0  1.0 -0.000019
# 9998 -1.477833e-06  3.453538e-07  6.624599e-06  0.000003  0.0  1.0  0.000088
# 9999 -1.281230e-06 -5.918294e-06 -5.402740e-06  0.000004  0.0  1.0  0.000034
#
# ...

# %%
bdsimOutput.get_sampler('QH9T20.')
# Out:
#       event_number             x            xp         y            yp    z  \
# 0                0 -1.078591e-05  1.780353e-06 -0.000018 -3.754918e-06  0.0
# 1                1  3.388700e-06  2.262307e-06  0.000031  4.694783e-06  0.0
# 2                2  3.137364e-06  1.620719e-06  0.000017  2.099670e-06  0.0
# 3                3  6.606978e-06  1.720679e-06 -0.000031 -8.205497e-06  0.0
# 4                4  8.531238e-06  1.458617e-07  0.000043  4.646849e-06  0.0
# ...            ...           ...           ...       ...           ...  ...
# 9995          9995 -8.488672e-07  1.833613e-06 -0.000024 -2.999681e-06  0.0
# 9996          9996  9.392115e-06 -3.642452e-06 -0.000020 -4.906674e-06  0.0
# 9997          9997 -1.212819e-05  1.051451e-06 -0.000017 -2.754527e-06  0.0
# 9998          9998 -8.117016e-07  1.298033e-06 -0.000015 -8.977608e-07  0.0
# 9999          9999 -8.343335e-06  2.031216e-06 -0.000029 -4.328928e-06  0.0
#
#        zp           T     energy  partID  trackID
# ...

# %%
bdsimOutput.get_sampler('QH9T20.')['yp'].iloc[0]
# Out:
# -3.7549177704931935e-06

# %%
bdsimOutput.get_sampler('DTOIP0.')
# Out:
#       event_number             x            xp             y        yp    z  \
# 0                0  5.958383e-06 -4.516484e-07 -5.751028e-06  0.000004  0.0
# 1                1 -1.346584e-06 -5.005735e-06 -1.058103e-06 -0.000005  0.0
# 2                2 -1.335177e-06 -3.770132e-06 -3.655403e-06 -0.000002  0.0
# 3                3 -3.126766e-06 -4.852023e-06 -2.015472e-05  0.000008  0.0
# 4                4 -4.423546e-06 -2.477877e-06 -1.234424e-05 -0.000006  0.0
# ...            ...           ...           ...           ...       ...  ...
# 9995          9995  7.841034e-07 -3.125060e-06  4.715403e-06  0.000003  0.0
# 9996          9996 -5.577750e-06  4.210103e-06 -1.059416e-05  0.000005  0.0
# 9997          9997  6.522914e-06  1.226105e-06 -4.098184e-07  0.000003  0.0
# 9998          9998  6.650429e-07 -2.157615e-06  8.517401e-06  0.000001  0.0
# 9999          9999  4.730919e-06 -1.542548e-06  7.306899e-07  0.000005  0.0
#
#        zp           T     energy  partID  trackID
# ...
