# %%
import os
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-backgrounds/06_analysis/')
import beamDump
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')

import numpy as _np
import matplotlib.pyplot as _plt
import pybdsim as _bd

from manchester_farm.background import beamGas
from manchester_farm.background import G4Dict
# Out:
# initializing ocelot...

# %%
hist_ebrem_1e3 = "manchester_farm/background/results/histfiles/14560978_0_100000_XTD8_test_bias_per_process_1e3_eBrem_hist.root"
hist_ebrem_1e4 = "manchester_farm/background/results/histfiles/14560994_0_100000_XTD8_test_bias_per_process_1e4_eBrem_hist.root"
hist_ebrem_1e5 = "manchester_farm/background/results/histfiles/14561007_0_100000_XTD8_test_bias_per_process_1e5_eBrem_hist.root"
hist_ebrem_1e6 = "manchester_farm/background/results/histfiles/14561031_0_100000_XTD8_test_bias_per_process_1e6_eBrem_hist.root"
hist_ebrem_5e6 = "manchester_farm/background/results/histfiles/14571685_0_100000_XTD8_test_bias_per_process_5e6_eBrem_hist.root"

# %%
beamGas.plotSameHistMultipleFiles([hist_ebrem_1e4, hist_ebrem_1e5, hist_ebrem_1e6, hist_ebrem_5e6], "PFH_S_fBremsstrahlung", 
                                  legend = ["eBrem 1e4", "eBrem 1e5", "eBrem 1e6", "eBrem 5e6"], ylabel=r"$N_{PFH}$",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
# Out:
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader

# %%
hist_coulomb_1e8 = "manchester_farm/background/results/histfiles/14561203_0_100000_XTD8_test_bias_per_process_1e8_Coulomb_hist.root"
hist_coulomb_1e9 = "manchester_farm/background/results/histfiles/14561210_0_100000_XTD8_test_bias_per_process_1e9_Coulomb_hist.root"
hist_coulomb_1e10 = "manchester_farm/background/results/histfiles/14571349_0_100000_XTD8_test_bias_per_process_1e10_Coulomb_hist.root"

# %%
beamGas.plotSameHistMultipleFiles([hist_coulomb_1e8, hist_coulomb_1e9, hist_coulomb_1e10], "PFH_S_fCoulombScattering", 
                                  legend = ["Coulomb 1e8", "Coulomb 1e9", "Coulomb 1e10"], ylabel=r"$N_{PFH}$",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
# Out:
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader

# %%
hist_elecNuc_1e8 = "manchester_farm/background/results/histfiles/14564950_0_100000_XTD8_test_bias_per_process_1e8_elecNuc_hist.root"
hist_elecNuc_1e9 = "manchester_farm/background/results/histfiles/14564964_0_100000_XTD8_test_bias_per_process_1e9_elecNuc_hist.root"
hist_elecNuc_2e9 = "manchester_farm/background/results/histfiles/14578852_0_100000_XTD8_test_bias_per_process_2e9_elecNuc_hist.root"
hist_elecNuc_3e9 = "manchester_farm/background/results/histfiles/14592361_0_100000_XTD8_test_bias_per_process_3e9_elecNuc_hist.root"

# %%
beamGas.plotSameHistMultipleFiles([hist_elecNuc_1e8, hist_elecNuc_1e9, hist_elecNuc_2e9, hist_elecNuc_3e9], "PFH_S_fHadronInelastic", 
                                  legend = ["elecNuc 1e8", "elecNuc 1e9", "elecNuc 2e9", "elecNuc 3e9"], ylabel=r"$N_{PFH}$",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
# Out:
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# REBDSIM analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader
