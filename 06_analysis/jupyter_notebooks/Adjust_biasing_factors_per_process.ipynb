# %% [markdown]
# # Adjust the cross section biasing for each processes

# %%
import os
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')

import numpy as _np
import matplotlib.pyplot as _plt

from manchester_farm.background import beamGas
# Out:
# initializing ocelot...

# %% [markdown]
# ### Date and save prefix

# %%
date = "2026_06_02"
save_name_prefix = "jupyter_notebooks/plots/EUXFEL/Background/" + date + "_EuXFEL_plot"

# %% [markdown]
# ## Coulomb scattering

# %%
coulomb_1e8 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_1e8_merged.root"
coulomb_5e8 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_5e8_merged.root"
coulomb_1e9 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_1e9_merged.root"
coulomb_5e9 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_5e9_merged.root"
coulomb_1e10 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_1e10_merged.root"
coulomb_5e10 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_5e10_merged.root"
coulomb_1e11 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_1e11_merged.root"
coulomb_5e11 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_5e11_merged.root"
coulomb_1e12 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Coulomb_1e12_merged.root"

# %%
beamGas.plotSameHistMultipleFiles([coulomb_1e9, coulomb_1e10, coulomb_1e11, coulomb_1e12], "PFH_S_fCoulombScattering", 
                                  legend = [r"$\chi_{\rm Coulomb} = 10^{9}$", r"$\chi_{\rm Coulomb} = 10^{10}$",
                                            r"$\chi_{\rm Coulomb} = 10^{11}$", r"$\chi_{\rm Coulomb} = 10^{12}$"], 
                                  ylabel=r"$N_{\rm PFH, unweighted}$", xlabel=r"$s$ [m]",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-backgrounds/06_analysis/')
_plt.savefig("{}_PFH_coulomb_unweighted.pdf".format(save_name_prefix), dpi=300, bbox_inches='tight')
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')
# Out:
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader

# %%
beamGas.plotSameHistMultipleFiles([coulomb_1e9, coulomb_1e10, coulomb_1e11, coulomb_1e12], "PFH_S_fCoulombScattering_weighted", 
                                  legend = [r"$\chi_{\rm Coulomb} = 10^{9}$", r"$\chi_{\rm Coulomb} = 10^{10}$",
                                            r"$\chi_{\rm Coulomb} = 10^{11}$", r"$\chi_{\rm Coulomb} = 10^{12}$"], 
                                  ylabel=r"$N_{\rm PFH}$", xlabel=r"$s$ [m]",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-backgrounds/06_analysis/')
_plt.savefig("{}_PFH_coulomb_weighted.pdf".format(save_name_prefix), dpi=300, bbox_inches='tight')
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')
# Out:
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader

# %% [markdown]
# ## Bremsstrahlung

# %%
ebrem_1e4 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_1e4_merged.root"
ebrem_5e4 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_5e4_merged.root"
ebrem_1e5 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_1e5_merged.root"
ebrem_5e5 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_5e5_merged.root"
ebrem_1e6 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_1e6_merged.root"
ebrem_5e6 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_5e6_merged.root"
ebrem_1e7 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_eBrem_1e7_merged.root"

# %%
beamGas.plotSameHistMultipleFiles([ebrem_1e4, ebrem_1e5, ebrem_1e6], "PFH_S_fBremsstrahlung", 
                                  legend = [r"$\chi_{\rm brem} = 10^4$", r"$\chi_{\rm brem} = 10^5$", r"$\chi_{\rm brem} = 10^6$"], 
                                  ylabel=r"$N_{\rm PFH, unweighted}$", xlabel=r"$s$ [m]",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', 
                                  logY=True, ylim=[0, 8e5], figsize=[12, 5])
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-backgrounds/06_analysis/')
_plt.savefig("{}_PFH_brem_unweighted.pdf".format(save_name_prefix), dpi=300, bbox_inches='tight')
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')
# Out:
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader

# %% [markdown]
# ## Hadronic inelastic

# %%
hadronic_1e6 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_1e6_merged.root"
hadronic_5e6 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_5e6_merged.root"
hadronic_1e7 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_1e7_merged.root"
hadronic_5e7 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_5e7_merged.root"
hadronic_1e8 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_1e8_merged.root"
hadronic_5e8 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_5e8_merged.root"
hadronic_1e9 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_1e9_merged.root"
hadronic_5e9 = "manchester_farm/background/results/mergedfiles/1000000_part_XTD8_Hadronic_5e9_merged.root"

# %%
beamGas.plotSameHistMultipleFiles([hadronic_5e8, hadronic_1e9, hadronic_5e9], "PFH_S_fHadronInelastic", 
                                  legend = [r"$\chi_{\rm hadronic} = 5\times 10^{8}$", r"$\chi_{\rm hadronic} = 10^{9}$", 
                                            r"$\chi_{\rm hadronic} = 5\times 10^{9}$"], 
                                  ylabel=r"$N_{\rm PFH, unweighted}$", xlabel=r"$s$ [m]",
                                  gmadfile = 'gmad_files/XTD8_matched_biasing.gmad', logY=True, figsize=[12, 5])
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-backgrounds/06_analysis/')
_plt.savefig("{}_PFH_hadronic_unweighted.pdf".format(save_name_prefix), dpi=300, bbox_inches='tight')
os.chdir('/Users/marindeniaud/PhD/PhD-git/luxe-elbex')
# Out:
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# REBDSIMCOMBINE analysis file - using RebdsimFile
# BDSIM output file - using DataLoader
# BDSIM output file - using DataLoader
